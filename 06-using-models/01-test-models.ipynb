# %% [markdown]
# ### Huggingface

# %% [markdown]
# ##### Reading the API Key from the vault

# %%
path = r"E:\Lenovo Ideapad 330\company-material\digital-workforce-transformation\ai-upskill-4\key-vault\huggingface\hg-api-key.txt"

# %%
import os

os.environ["OPENAI_API_KEY"] = "sk-proj"

api_key = os.getenv("OPENAI_API_KEY")
print(api_key[:10])
# Out:
# sk-proj-u8

# %%
from openai import OpenAI

client = OpenAI()

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "Explain AI in simple terms"}
    ]
)

print(response.choices[0].message.content)
# Out:
# AI, or artificial intelligence, is a type of technology that allows machines and computers to perform tasks that normally require human intelligence. This includes things like understanding language, recognizing images, solving problems, and making decisions.
#
# You can think of it like teaching a computer to learn from experience. For instance, just as people learn from practice—like riding a bike or playing a game—AI systems can learn from data and improve over time. The goal is to make computers smart enough to assist us or even perform tasks on their own.
#
# In simple terms, AI is like giving machines a brain so they can think and act in ways that are helpful to us.

# %%
def ask_ai(prompt):
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}]
    )
    return response.choices[0].message.content

print(ask_ai("Explain phishing attack"))
# Out:
# A phishing attack is a type of cybercrime in which attackers attempt to deceive individuals into providing sensitive information, such as login credentials, credit card numbers, or personal identification details. This is typically achieved through the use of fraudulent emails, messages, or websites that appear to be from legitimate sources.
#
# ### Key Characteristics of Phishing Attacks:
#
# 1. **Deceptive Communication**: Attackers usually send emails or messages that look like they come from trusted organizations, such as banks, social media platforms, or government agencies. The communication may urge the recipient to click on a link or download an attachment.
#
# 2. **Imitation of Legitimate Sources**: The emails may include logos, formatting, and language that resemble the genuine organization's communications to increase their credibility and trick the recipient.
#
# ...

# %%
api_key[:9]
# Out:
# 'sk-proj-u'

# %%
#!pip install openai

# %%
import os
from openai import OpenAI

# %% [markdown]
# ###### Alternatively, we can use python's requests module for sending the HTTP request to the HF server

# %%
client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key=api_key
)
client

# %%
response = client.chat.completions.create(
    model="Qwen/Qwen2.5-72B-Instruct:fastest",
    messages=[
        {"role": "system", "content":"You are a helpful and brief AI."},
        {"role": "user", "content": "Tell me 5 facts about Voyager 1"}
    ],
    max_tokens=500,
)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 response = client.chat.completions.create(
#       2     model="Qwen/Qwen2.5-72B-Instruct:fastest",
#       3     messages=[
#       4         {"role": "system", "content":"You are a helpful and brief AI."},
#
# File ~/Documents/ai-upskill/ey-upskill-b5-19052026/ai/lib/python3.11/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# ...

# %%
print(response.choices[0].message.content)
# Out:
# 1. **Launch Date**: Voyager 1 was launched on September 5, 1977.
# 2. **Farthest Human-Made Object**: As of 2023, Voyager 1 is the farthest human-made object from Earth, traveling in interstellar space.
# 3. **Interstellar Space**: In 2012, Voyager 1 became the first spacecraft to enter interstellar space, beyond the heliosphere.
# 4. **Golden Record**: It carries a Golden Record containing sounds and images selected to portray the diversity of life and culture on Earth.
# 5. **Power Source**: Voyager 1 is powered by three radioisotope thermoelectric generators (RTGs) that convert heat from decaying plutonium into electricity.

# %% [markdown]
# ### GROQ - https://groq.com/

# %%
# !pip install groq
# Out:
# ...
#   Using cached groq-1.2.0-py3-none-any.whl.metadata (16 kB)
# ...
# Using cached groq-1.2.0-py3-none-any.whl (142 kB)
# ...
#
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ##### Using OpenAI Client

# %%
f = open(r"E:\Lenovo Ideapad 330\company-material\digital-workforce-transformation\ai-upskill-4\key-vault\groq\groq-api-key.txt")
groq_api_key = f.read()
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 with open("key.txt", "r") as f:
#       2     api_key = f.read()
#       3
#       4 print(api_key[:10])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'key.txt'

# %%
import os
from groq import Groq

client = Groq(api_key=os.getenv("GROQ_API_KEY"))

# %%
from groq import Groq

client = Groq(api_key="gsk_your_key_here")

response = client.chat.completions.create(
    model="llama3-8b-8192",
    messages=[{"role": "user", "content": "What is cybersecurity?"}]
)

print(response.choices[0].message.content)

# %%
client = Groq(api_key=groq_api_key)

# %%
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {"role": "system", "content":"You are a helpful and brief AI."},
        {"role": "user", "content": "Tell me 5 facts about Voyager 1"}
    ],
    max_tokens=500,
)

# %%
print(response.choices[0].message.content)
# Out:
# Here are five facts about Voyager 1:
#
# 1. **Launched in 1977**: Voyager 1 was launched on September 5, 1977, with the primary goal of studying the outer Solar System.
# 2. **Farthest human-made object**: Voyager 1 is the most distant human-made object in space, with a distance of over 14.5 billion miles (23.3 billion kilometers) from Earth.
# 3. **Interstellar space**: In 2012, Voyager 1 entered interstellar space, becoming the first spacecraft to leave the Solar System.
# 4. **Golden Record**: Voyager 1 carries a Golden Record, a gold-plated copper record containing sounds and images of Earth, which will serve as a message to any extraterrestrial life form that may encounter the spacecraft.
# 5. **Power source**: Voyager 1 is powered by a small radioisotope thermoelectric generator (RTG), which converts the heat generated by the decay of radioactive isotopes into electricity.
