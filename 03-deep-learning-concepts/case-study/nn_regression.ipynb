# %%
path = r'kc_house_data.csv'

import sys
print(sys.executable)
# Out:
# /Users/lightovic/Documents/ai-upskill/dl/bin/python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(path)
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='str')

# %% [markdown]
# ### EDA

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
sns.histplot(df['price'])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.countplot(df['bedrooms'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.scatterplot(x='price', y='sqft_living', data=df)
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
sns.scatterplot(x='long', y='price', data=df)
# Out:
# <Axes: xlabel='long', ylabel='price'>

# %%
sns.scatterplot(x='lat', y='price', data=df)
# Out:
# <Axes: xlabel='lat', ylabel='price'>

# %%
sns.scatterplot(x='lat', y='long', data=df, hue='price')
# Out:
# <Axes: xlabel='lat', ylabel='long'>

# %%
sns.boxplot(x='waterfront', y='price', data=df)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %% [markdown]
# ### Prepare the Data

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df = df.drop('id', axis=1)

# %%
df['date'] = pd.to_datetime(df['date'])
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503

# %%
df['month'] = df['date'].apply(lambda d : d.month)
df['year'] = df['date'].apply(lambda d : d.year)
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  month  year
# 0    98178  47.5112 -122.257           1340        5650     10  2014
# 1    98125  47.7210 -122.319           1690        7639     12  2014
# 2    98028  47.7379 -122.233           2720        8062      2  2015
# 3    98136  47.5208 -122.393           1360        5000     12  2014
# 4    98074  47.6168 -122.045           1800        7503      2  2015
#
# [5 rows x 22 columns]

# %%
df.groupby('month').mean()['price'].plot()
# Out:
# <Axes: xlabel='month'>

# %%
df.groupby('year').mean()['price'].plot()
# Out:
# <Axes: xlabel='year'>

# %%
df = df.drop('date',axis=1)

# %% [markdown]
# ### Training

# %%
# !pip install scikit-learn tensorflow
# Out:
# Requirement already satisfied: scikit-learn in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: tensorflow in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (2.21.0)
# Requirement already satisfied: numpy>=1.24.1 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from scikit-learn) (2.4.6)
# Requirement already satisfied: scipy>=1.10.0 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from tensorflow) (7.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from tensorflow) (2.34.2)
# Requirement already satisfied: setuptools in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from tensorflow) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from tensorflow) (3.14.1)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.16)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.5.20)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from rich->keras>=3.12.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/lightovic/Documents/ai-upskill/dl/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
#
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.16.2

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam

# %%
import pandas as pd

df = pd.read_csv("kc_house_data.csv")
X = df.drop('price',axis=1)
y = df['price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.1,random_state=101)

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 from sklearn.preprocessing import MinMaxScaler
#       2 scaler = MinMaxScaler()
# ----> 3 X_train= scaler.fit_transform(X_train)
#       4 X_test = scaler.transform(X_test)
#
# File ~/Documents/ai-upskill/dl/lib/python3.11/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~/Documents/ai-upskill/dl/lib/python3.11/site-packages/sklearn/base.py:907, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     892         warnings.warn(
#     893             (
#     894                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)    902             UserWarning,
#     903         )
#     905 if y is None:
#     906     # fit method of arity 1 (unsupervised transformation)
# --> 907     return self.fit(X, **fit_params).transform(X)
#     908 else:
#     909     # fit method of arity 2 (supervised transformation)
#     910     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/Documents/ai-upskill/dl/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:471, in MinMaxScaler.fit(self, X, y)
#     469 # Reset internal state before fitting
#     470 self._reset()
# --> 471 return self.partial_fit(X, y)
#
# File ~/Documents/ai-upskill/dl/lib/python3.11/site-packages/sklearn/base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/ai-upskill/dl/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:511, in MinMaxScaler.partial_fit(self, X, y)
#     508 xp, _ = get_namespace(X)
#     510 first_pass = not hasattr(self, "n_samples_seen_")
# --> 511 X = validate_data(
#     512     self,
#     513     X,
#     514     reset=first_pass,
#     515     dtype=_array_api.supported_float_dtypes(xp),
#     516     ensure_all_finite="allow-nan",
#     517 )
#     519 device_ = device(X)
#     520 feature_range = (
#     521     xp.asarray(feature_range[0], dtype=X.dtype, device=device_),
#     522     xp.asarray(feature_range[1], dtype=X.dtype, device=device_),
#     523 )
#
# File ~/Documents/ai-upskill/dl/lib/python3.11/site-packages/sklearn/utils/validation.py:2902, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2900         out = X, y
#    2901 elif not no_val_X and no_val_y:
# -> 2902     out = check_array(X, input_name="X", **check_params)
#    2903 elif no_val_X and not no_val_y:
#    2904     out = _check_y(y, **check_params)
#
# File ~/Documents/ai-upskill/dl/lib/python3.11/site-packages/sklearn/utils/validation.py:1022, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1020         array = xp.astype(array, dtype, copy=False)
#    1021     else:
# -> 1022         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1023 except ComplexWarning as complex_warning:
#    1024     raise ValueError(
#    1025         "Complex data not supported\n{}\n".format(array)
#    1026     ) from complex_warning
#
# File ~/Documents/ai-upskill/dl/lib/python3.11/site-packages/sklearn/utils/_array_api.py:878, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     876     array = numpy.array(array, order=order, dtype=dtype)
#     877 else:
# --> 878     array = numpy.asarray(array, order=order, dtype=dtype)
#     880 # At this point array is a NumPy ndarray. We convert it to an array
#     881 # container that is consistent with the input's namespace.
#     882 return xp.asarray(array)
#
# File ~/Documents/ai-upskill/dl/lib/python3.11/site-packages/pandas/core/generic.py:2039, in NDFrame.__array__(self, dtype, copy)
#    2035             )
#    2036         values = self._values
#    2037         if copy is None:
#    2038             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2039             arr = np.asarray(values, dtype=dtype)
#    2040         else:
#    2041             arr = np.array(values, dtype=dtype, copy=copy)
#    2042
#
# ValueError: could not convert string to float: '5/8/2014'

# %% [markdown]
# ### Model Creation

# %%
model = Sequential()

model.add(Dense(19,activation='relu'))

model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
model.fit(
    x=X_train,
    y=y_train.values,
    validation_data=(X_test,y_test.values),
    batch_size=128,
    epochs=100
)
# Out:
# Epoch 1/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 430242988032.0000 - val_loss: 418930819072.0000
# Epoch 2/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 429374177280.0000 - val_loss: 415886311424.0000
# Epoch 3/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 416584597504.0000 - val_loss: 386063302656.0000
# Epoch 4/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 349593632768.0000 - val_loss: 273742774272.0000
# Epoch 5/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 202103488512.0000 - val_loss: 126211497984.0000
# Epoch 6/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 109759062016.0000 - val_loss: 98195718144.0000
# Epoch 7/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 100499775488.0000 - val_loss: 96539590656.0000
# Epoch 8/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 98745409536.0000 - val_loss: 94899249152.0000
# Epoch 9/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 96993574912.0000 - val_loss: 93244628992.0000
# Epoch 10/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 95246147584.0000 - val_loss: 91536056320.0000
# Epoch 11/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 93403414528.0000 - val_loss: 89712410624.0000
# Epoch 12/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 91466424320.0000 - val_loss: 87965007872.0000
# Epoch 13/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 89567272960.0000 - val_loss: 85921619968.0000
# Epoch 14/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 87516250112.0000 - val_loss: 83946037248.0000
# Epoch 15/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 85371551744.0000 - val_loss: 81804247040.0000
# Epoch 16/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 83115696128.0000 - val_loss: 79570993152.0000
# Epoch 17/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 80742899712.0000 - val_loss: 77175357440.0000
# Epoch 18/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 78253146112.0000 - val_loss: 74952572928.0000
# Epoch 19/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 75664080896.0000 - val_loss: 72044838912.0000
# Epoch 20/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 72930353152.0000 - val_loss: 69421465600.0000
# Epoch 21/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 70192939008.0000 - val_loss: 66731753472.0000
# Epoch 22/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 67450429440.0000 - val_loss: 64227303424.0000
# Epoch 23/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 64706748416.0000 - val_loss: 61545218048.0000
# Epoch 24/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 62146482176.0000 - val_loss: 59107381248.0000
# Epoch 25/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 59741642752.0000 - val_loss: 56913702912.0000
# Epoch 26/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 57517264896.0000 - val_loss: 54909775872.0000
# Epoch 27/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 55552991232.0000 - val_loss: 53278445568.0000
# Epoch 28/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 53904044032.0000 - val_loss: 51720671232.0000
# Epoch 29/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 52476411904.0000 - val_loss: 50638028800.0000
# Epoch 30/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 51341787136.0000 - val_loss: 49500966912.0000
# Epoch 31/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 50310111232.0000 - val_loss: 48595668992.0000
# Epoch 32/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 49407758336.0000 - val_loss: 47879532544.0000
# Epoch 33/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 48596144128.0000 - val_loss: 47018795008.0000
# Epoch 34/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47818846208.0000 - val_loss: 46313099264.0000
# Epoch 35/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47136608256.0000 - val_loss: 45611925504.0000
# Epoch 36/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46438731776.0000 - val_loss: 44975153152.0000
# Epoch 37/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45805789184.0000 - val_loss: 44434792448.0000
# Epoch 38/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45241438208.0000 - val_loss: 43874443264.0000
# Epoch 39/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 44637544448.0000 - val_loss: 43270754304.0000
# Epoch 40/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 44099035136.0000 - val_loss: 42765918208.0000
# Epoch 41/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43590995968.0000 - val_loss: 42419011584.0000
# Epoch 42/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 43128053760.0000 - val_loss: 41804996608.0000
# Epoch 43/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42646044672.0000 - val_loss: 41370247168.0000
# Epoch 44/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42228424704.0000 - val_loss: 40919724032.0000
# Epoch 45/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41725730816.0000 - val_loss: 40617238528.0000
# Epoch 46/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41341927424.0000 - val_loss: 40082448384.0000
# Epoch 47/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40880779264.0000 - val_loss: 39709749248.0000
# Epoch 48/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40495894528.0000 - val_loss: 39309758464.0000
# Epoch 49/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 40071565312.0000 - val_loss: 38929969152.0000
# Epoch 50/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39695007744.0000 - val_loss: 38563950592.0000
# Epoch 51/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39343185920.0000 - val_loss: 38189191168.0000
# Epoch 52/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 39020724224.0000 - val_loss: 38025019392.0000
# Epoch 53/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 38749184000.0000 - val_loss: 37603520512.0000
# Epoch 54/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 38436700160.0000 - val_loss: 37348409344.0000
# Epoch 55/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 38193713152.0000 - val_loss: 37085614080.0000
# Epoch 56/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 37929361408.0000 - val_loss: 36863574016.0000
# Epoch 57/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 37677457408.0000 - val_loss: 36655144960.0000
# Epoch 58/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 37421711360.0000 - val_loss: 36440276992.0000
# Epoch 59/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 37225291776.0000 - val_loss: 36331589632.0000
# Epoch 60/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 37045444608.0000 - val_loss: 36059492352.0000
# Epoch 61/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 36819128320.0000 - val_loss: 35891216384.0000
# Epoch 62/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 36636631040.0000 - val_loss: 35797733376.0000
# Epoch 63/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 36518858752.0000 - val_loss: 35576045568.0000
# Epoch 64/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 36292198400.0000 - val_loss: 35419652096.0000
# Epoch 65/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 36183572480.0000 - val_loss: 35288608768.0000
# Epoch 66/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 35975770112.0000 - val_loss: 35150127104.0000
# Epoch 67/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 35816022016.0000 - val_loss: 34994499584.0000
# Epoch 68/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 35663962112.0000 - val_loss: 34859511808.0000
# Epoch 69/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35494707200.0000 - val_loss: 34716733440.0000
# Epoch 70/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35333517312.0000 - val_loss: 34560266240.0000
# Epoch 71/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 35187855360.0000 - val_loss: 34390151168.0000
# Epoch 72/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 35000885248.0000 - val_loss: 34290788352.0000
# Epoch 73/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 34844024832.0000 - val_loss: 34116812800.0000
# Epoch 74/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 34693230592.0000 - val_loss: 34096449536.0000
# Epoch 75/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34552639488.0000 - val_loss: 33844269056.0000
# Epoch 76/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34400772096.0000 - val_loss: 33760243712.0000
# Epoch 77/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 34271440896.0000 - val_loss: 33588973568.0000
# Epoch 78/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34185670656.0000 - val_loss: 33470210048.0000
# Epoch 79/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 34050930688.0000 - val_loss: 33434378240.0000
# Epoch 80/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33938778112.0000 - val_loss: 33241241600.0000
# Epoch 81/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33797750784.0000 - val_loss: 33204236288.0000
# Epoch 82/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33668849664.0000 - val_loss: 33037017088.0000
# Epoch 83/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33554919424.0000 - val_loss: 32996759552.0000
# Epoch 84/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33431861248.0000 - val_loss: 32868245504.0000
# Epoch 85/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33324077056.0000 - val_loss: 32744708096.0000
# Epoch 86/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33238167552.0000 - val_loss: 32685006848.0000
# Epoch 87/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33126641664.0000 - val_loss: 32544921600.0000
# Epoch 88/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33004261376.0000 - val_loss: 32550932480.0000
# Epoch 89/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33008998400.0000 - val_loss: 32391231488.0000
# Epoch 90/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32881147904.0000 - val_loss: 32396447744.0000
# Epoch 91/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 32777224192.0000 - val_loss: 32247267328.0000
# Epoch 92/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 32724451328.0000 - val_loss: 32228931584.0000
# Epoch 93/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 32624179200.0000 - val_loss: 32125579264.0000
# Epoch 94/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32582500352.0000 - val_loss: 32063219712.0000
# Epoch 95/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 32500668416.0000 - val_loss: 31988480000.0000
# Epoch 96/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 32409905152.0000 - val_loss: 32019367936.0000
# Epoch 97/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 32341884928.0000 - val_loss: 31864154112.0000
# Epoch 98/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 32334643200.0000 - val_loss: 31787970560.0000
# Epoch 99/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 32266604544.0000 - val_loss: 31736670208.0000
# Epoch 100/100
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 32174970880.0000 - val_loss: 31680608256.0000

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Evaluation

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
predictions = model.predict(X_test)
# Out:
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 110189.33227765119

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 177990.4684636187

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.7611222533156162

# %%
df['price'].mean()
# Out:
# 540296.5735055795

# %%
# Our predictions
plt.scatter(y_test,predictions)

# Perfect predictions
plt.plot(y_test,y_test,'r')

# %% [markdown]
# ### Predicting for brand new house

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  month  year
# 0    98178  47.5112 -122.257           1340        5650     10  2014
# 1    98125  47.7210 -122.319           1690        7639     12  2014
# 2    98028  47.7379 -122.233           2720        8062      2  2015
# 3    98136  47.5208 -122.393           1360        5000     12  2014
# 4    98074  47.6168 -122.045           1800        7503      2  2015
#
# [5 rows x 21 columns]

# %%
single_house = df.drop('price', axis=1).iloc[0]
single_house.shape
# Out:
# (20,)

# %%
single_house = scaler.transform(single_house.values.reshape(-1, 20))
# Out:
# C:\Users\mindf\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
single_house
# Out:
# array([[0.2       , 0.08      , 0.08376422, 0.00310751, 0.        ,
#         0.        , 0.        , 0.5       , 0.4       , 0.10785619,
#         0.        , 0.47826087, 0.        , 0.89393939, 0.57149751,
#         0.21760797, 0.16193426, 0.00582059, 0.81818182, 0.        ]])

# %%
model.predict(single_house)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# array([[245501.2]], dtype=float32)
